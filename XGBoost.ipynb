# %% [markdown]
# # XGBoost with Shap

# %%
#!pip install shap

# %%
import matplotlib.pylab as pl
import xgboost
from sklearn.model_selection import train_test_split

import shap
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
X, y = shap.datasets.nhanesi()
X_display, y_display = shap.datasets.nhanesi(
    display=True
)  #

# %%
y
# Out:
# array([-16.91666667, -17.16666667, -17.66666667, ..., -17.08333333,
#        -17.08333333, -17.08333333])

# %%
import pandas as pd
df = pd.read_csv('miRNAexpression_dayssurvival.csv')
df.head()
# Out:
#    hsa-let-7a-1  hsa-let-7a-2  hsa-let-7a-3  hsa-let-7b  hsa-let-7c  \
# 0       12.5118       13.5062       12.5058     13.1423      9.4597
# 1       12.8151       13.8253       12.8277     13.0250      8.0617
# 2       13.9389       14.9395       13.9522     14.2588      8.8684
# 3       13.7992       14.8060       13.8097     14.8904     11.5533
# 4       13.6592       14.6622       13.6761     14.4914      9.4091
#
#    hsa-let-7d  hsa-let-7e  hsa-let-7f-1  hsa-let-7f-2  hsa-let-7g  ...  \
# 0      9.1296     11.3277        4.5361       13.1852      8.7630  ...
# 1      9.6969      9.6906        4.6816       14.1684      9.4817  ...
# 2      9.0935     10.8985        5.9200       14.9715     10.4961  ...
# 3      9.5417      9.7590        4.8165       13.8766      9.4976  ...
# 4      9.2256      9.4294        6.3407       13.8757      9.8671  ...
#
#    hsa-mir-941-1  hsa-mir-942  hsa-mir-943  hsa-mir-944  hsa-mir-95  \
# 0            0.0       2.4290       0.0000       7.0844      4.4115
# 1            0.0       4.3008       0.2781       9.5068      1.5428
# 2            0.0       4.1204       0.0000       8.7194      4.2529
# 3            0.0       3.2618       0.0000       7.5526      2.5631
# 4            0.0       4.7225       0.0000       7.6184      2.6753
#
#    hsa-mir-96  hsa-mir-98  hsa-mir-99a  hsa-mir-99b   Survival
# 0      3.2474      5.8341       7.7704      14.8284   3.353388
# 1      5.5523      6.5335       5.1035      14.0989  12.788901
# 2      4.5285      6.3210       4.7599      14.2215  42.344741
# 3      5.6962      6.5749       8.7677      13.6794   8.153335
# 4      4.1333      5.6403       6.3945      13.7741  23.835355
#
# [5 rows x 843 columns]

# %%
Y=df['Survival']
print(Y)
y=pd.DataFrame(Y)
l=y.to_numpy()

m=l.ravel()

m
# Out:
# 0       3.353388
# 1      12.788901
# 2      42.344741
# 3       8.153335
# 4      23.835355
#          ...
# 478    17.062827
# 479    23.605221
# 480     1.808199
# 481    17.029950
# 482    14.564224
# Name: Survival, Length: 483, dtype: float64
# array([3.35338791e+00, 1.27889009e+01, 4.23447414e+01, 8.15333531e+00,
#        2.38353552e+01, 2.04819673e+01, 6.55883223e+01, 5.30624322e+01,
#        1.13094651e+01, 2.11723707e+01, 1.48272348e+01, 3.55064602e+00,
#        1.26245192e+01, 2.16983923e+00, 4.18515961e+01, 1.52217510e+01,
#        2.81092810e+01, 2.04490910e+01, 6.47664135e+00, 2.79120229e+01,
#        1.15395996e+01, 6.83828122e+00, 3.15612980e+00, 1.44655949e+01,
#        7.82457179e+00, 2.26846829e+00, 8.74510964e+00, 7.89032449e+00,
#        2.04819673e+01, 1.64052997e+01, 6.14787783e+00, 2.79448992e+00,
#        2.24216721e+01, 3.67228852e+01, 3.36982608e+01, 5.02021896e+01,
#        4.49748496e+01, 6.62787257e+01, 1.40710787e+01, 3.83995792e+01,
#        7.10457968e+01, 1.44655949e+01, 2.57093073e+01, 7.56156097e+00,
#        1.43998422e+01, 6.96978663e+00, 6.27938324e+00, 1.26902719e+01,
#        5.21418943e+01, 1.43340895e+01, 4.28050104e+01, 1.30519118e+01,
#        4.76707105e+00, 4.04379130e+00, 1.77532301e+01, 3.06736365e+01,
#        4.79994740e+01, 1.06190617e+01, 4.74405760e+01, 2.80435283e+01,
#        1.90682842e+01, 3.41256534e+01, 6.73965217e+00, 9.07387316e+00,
#        3.32051156e+00, 5.20761416e+01, 5.12871092e+00, 1.04546799e+01,
#        1.43340895e+01, 3.50461913e+01, 3.88927245e+01, 3.68215143e+00,
#        1.15067232e+01, 9.17250222e+00, 8.02182990e+00, 3.50133149e+01,
#        6.11500148e+00, 2.35723444e+01, 1.13094651e+01, 2.97202222e+01,
#        2.12052471e+01, 7.39717921e+00, 3.16928034e+01, 2.23230430e+01,
#        1.23943847e+01, 1.65696814e+01, 4.40543117e+00, 1.20656212e+01,
#        2.69586087e+00, 2.34408390e+01, 1.98244403e+01, 2.43942532e+01,
#        2.08764835e+01, 1.95285531e+01, 4.81967321e+01, 5.23720288e+01,
#        6.70677582e+00, 2.92599533e+00, 5.45747444e+01, 7.04540224e+01,
#        6.23664398e+01, 4.59940165e+01, 1.04218036e+01, 5.78623796e+00,
#        1.64381760e+00, 4.11940691e+01, 6.41088865e+00, 3.23832068e+01,
#        6.62787257e+01, 4.69474307e+01, 5.65802019e+01, 5.91774337e+00,
#        4.24104941e+00, 8.97524411e+00, 3.87612191e+01, 3.81365684e+01,
#        6.48650426e+01, 7.56156097e+00, 1.67340632e+01, 3.77420521e+01,
#        4.18844725e+01, 4.31008975e+01, 7.75553145e+01, 4.44817043e+01,
#        9.43551304e+00, 0.00000000e+00, 2.93585824e+01, 3.35996318e+01,
#        2.94900878e+01, 1.15067232e+01, 6.90403393e+00, 1.69970740e+01,
#        8.42292139e+01, 1.17697340e+01, 3.07722655e+01, 3.78735576e+01,
#        2.62682053e+01, 5.84212776e+01, 5.00049315e+01, 1.63724233e+01,
#        3.45201696e+01, 3.69858961e+01, 7.23279745e+00, 1.68984449e+01,
#        6.01637242e+00, 1.19012394e+01, 1.02245455e+01, 1.13423414e+01,
#        1.16382286e+01, 7.69306638e+00, 1.24601374e+01, 1.64052997e+01,
#        1.57477726e+01, 8.12045895e+00, 4.71775652e+01, 3.91557353e+01,
#        4.73419469e+01, 4.09310583e+01, 3.58352237e+01, 3.45201696e+00,
#        3.09037709e+00, 2.49531512e+01, 2.92270770e+01, 9.86290561e-01,
#        3.19558142e+01, 9.17250222e+00, 3.40599007e+01, 1.84436335e+01,
#        2.01860801e+01, 1.49258638e+01, 3.27777230e+01, 3.37968899e+01,
#        1.09807016e+01, 1.28875300e+01, 4.95775389e+01, 3.00161094e+01,
#        4.68488017e+01, 3.26462176e+01, 4.42515699e+01, 3.05750074e+01,
#        2.47887694e+01, 5.12871092e+00, 5.95061972e+00, 3.54078311e+01,
#        2.99503567e+01, 7.69306638e+00, 2.57421837e+01, 1.71614558e+01,
#        1.29204063e+02, 6.11171384e+01, 9.33688398e+00, 1.91997896e+01,
#        6.93691028e+00, 1.07505671e+02, 9.48811520e+01, 7.65032712e+01,
#        9.15277641e+01, 8.01196699e+01, 1.79176119e+01, 1.33477989e+01,
#        2.30463228e+01, 8.68264457e+01, 4.85912483e+01, 6.04924878e+01,
#        7.06841569e+00, 4.32324029e+01, 5.47391261e+01, 2.10737417e+01,
#        6.24321925e+01, 3.12325344e+00, 9.01140809e+01, 2.13696288e+00,
#        9.69852385e+00, 5.16158727e+00, 2.05148437e+01, 4.73419469e+00,
#        2.18956505e+01, 2.64325870e+01, 1.12437124e+01, 1.40776539e+02,
#        1.97915639e+01, 1.20327449e+01, 4.23776178e+01, 8.48209883e+00,
#        3.00818621e+01, 6.08212513e+00, 5.00049315e+01, 6.58184568e+01,
#        1.09807016e+01, 7.13416839e+00, 3.38626426e+00, 2.83394155e+01,
#        2.49860275e+00, 4.14242036e+00, 6.48321662e+01, 1.72666601e+02,
#        1.11154946e+02, 1.88052734e+01, 1.26573955e+01, 7.98895355e+00,
#        9.00812046e+00, 5.26021633e+00, 1.84107571e+00, 5.23062761e+01,
#        1.29204064e+01, 2.17970214e+01, 7.12101785e+01, 1.07505671e+01,
#        1.30880757e+02, 7.71607982e+01, 4.73419469e+00, 8.96538120e+01,
#        3.59996055e+01, 3.13640399e+01, 2.62024526e+01, 1.89696551e+01,
#        1.71285794e+01, 3.64927508e+00, 4.96432916e+00, 1.18683631e+01,
#        4.79665976e+01, 2.10408653e+00, 4.97090443e+01, 1.84107571e+01,
#        5.74678634e+01, 3.55393366e+01, 1.78518592e+01, 2.10967551e+02,
#        8.93250485e+01, 9.66564750e+00, 4.60268929e-01, 2.28490647e+01,
#        2.50846566e+01, 1.62409179e+01, 6.57527040e-02, 2.40983660e+01,
#        1.00568761e+02, 1.48929875e+01, 5.64815728e+01, 1.07900187e+02,
#        5.49363843e+01, 3.51776967e+00, 1.62737943e+01, 8.44922247e+01,
#        1.46299767e+01, 7.16704475e+00, 1.53861328e+02, 1.66354341e+01,
#        6.37801230e+00, 2.21915376e+01, 3.59338528e+01, 3.04763783e+01,
#        2.79777756e+01, 2.10079890e+01, 1.69378966e+02, 1.80162409e+02,
#        1.59647566e+02, 3.49804386e+01, 1.05204327e+00, 4.59611401e+01,
#        6.50951770e+00, 7.62073840e+01, 4.81967321e+01, 4.68488017e+01,
#        6.78567906e+01, 7.56156097e-01, 9.20537857e-01, 7.06841569e+00,
#        1.52546273e+01, 5.98349607e+00, 3.53420784e+01, 3.51776967e+00,
#        2.97859749e+01, 4.17529671e+00, 2.80106519e+01, 3.61639872e+00,
#        2.12381234e+01, 1.29204064e+01, 4.79994740e+00, 1.31834172e+01,
#        4.40543117e+00, 3.02462439e+00, 1.88381497e+01, 3.43557879e+01,
#        5.11227274e+01, 6.41088865e+00, 2.54134201e+01, 5.29309268e+00,
#        2.30463228e+01, 2.53147911e+00, 1.61422888e+01, 1.14409705e+01,
#        1.86737680e+01, 2.49531512e+01, 2.53147911e+01, 1.77203538e+01,
#        1.23615084e+01, 2.87668080e+01, 7.62731367e+00, 2.25860538e+01,
#        2.49531512e+01, 1.39395733e+01, 1.20984975e+01, 1.27889009e+01,
#        2.33422100e+01, 5.84541539e+01, 3.47831805e+01, 3.09366473e+01,
#        3.38626426e+01, 1.46957294e+01, 2.59723181e+00, 4.63227800e+01,
#        4.64542854e+01, 2.04490910e+01, 3.75776704e+01, 4.02406549e+01,
#        3.56379656e+01, 3.91228589e+01, 4.50406023e+00, 3.71831542e+01,
#        3.27119703e+01, 2.16326396e+01, 2.02518329e+01, 3.02462439e+00,
#        3.11339054e+01, 7.00266298e+00, 2.49531512e+01, 4.60268929e-01,
#        1.78518592e+01, 1.18026104e+01, 2.02518329e+01, 1.24272611e+01,
#        8.28484071e+00, 1.51559983e+01, 1.50573692e+01, 7.72594273e+00,
#        2.11066180e+01, 2.09422363e+01, 5.32596903e+00, 2.84709209e+01,
#        2.57421837e+01, 2.19285268e+01, 2.74846303e+01, 2.74846303e+01,
#        5.62185620e+00, 2.20271559e+01, 1.26573955e+01, 2.28490647e+01,
#        3.61639872e-01, 1.37751915e+01, 4.27392577e+00, 3.64927508e+00,
#        6.90403393e+00, 3.47503041e+01, 1.59450307e+01, 3.85310846e+01,
#        1.44984712e+01, 3.77091758e+01, 8.18621166e+00, 3.74132886e+01,
#        6.57527040e-02, 3.35667554e+01, 5.29309268e+00, 5.12871092e+00,
#        1.38409442e+01, 1.54847618e+01, 1.27889009e+01, 1.81477463e+01,
#        1.92655423e+01, 3.61639872e+00, 1.43669658e+01, 7.95607719e+00,
#        3.00489858e+01, 1.84107571e+00, 1.26245192e+01, 6.24650689e+00,
#        5.88486702e+00, 7.13416839e+00, 8.08758260e+00, 1.11450833e+01,
#        2.99174804e+01, 9.20537857e+00, 5.26350396e+01, 5.12542328e+01,
#        4.60268929e+00, 3.68215143e+01, 4.70131834e+01, 1.19998685e+01,
#        7.55498570e+01, 7.95607719e+00, 2.03833383e+00, 1.10135779e+01,
#        8.97524411e+00, 1.60107834e+01, 1.31505408e+01, 1.81806227e+01,
#        2.12052471e+01, 1.65039287e+01, 4.66844199e+00, 7.49580826e+00,
#        5.78623796e+00, 1.27231482e+01, 2.73860012e+01, 2.01532038e+01,
#        1.97258112e+01, 1.28875300e+01, 5.62185620e+00, 6.73965217e+00,
#        1.21971266e+01, 1.78189828e+01, 1.53203801e+01, 8.31771707e+00,
#        1.11122070e+01, 1.69641976e+01, 6.87115758e+00, 7.52868462e+00,
#        7.10129204e+00, 3.24489595e+01, 1.37094388e+01, 1.51231219e+00,
#        1.35450570e+01, 1.32491699e+01, 2.03504619e+01, 6.47992899e+01,
#        5.46733734e+01, 2.82736628e+00, 4.95117862e+01, 4.80323503e+01,
#        4.94460335e+01, 4.46460861e+01, 7.44649374e+01, 7.52868462e+00,
#        2.42956242e+01, 5.54295295e+01, 2.94572114e+01, 1.80491173e+01,
#        1.12108360e+01, 1.72600848e+01, 1.70628267e+01, 2.36052208e+01,
#        1.80819936e+00, 1.70299504e+01, 1.45642240e+01])

# %%
df=df.drop('Survival', axis=1)
df.head()
# Out:
#    hsa-let-7a-1  hsa-let-7a-2  hsa-let-7a-3  hsa-let-7b  hsa-let-7c  \
# 0       12.5118       13.5062       12.5058     13.1423      9.4597
# 1       12.8151       13.8253       12.8277     13.0250      8.0617
# 2       13.9389       14.9395       13.9522     14.2588      8.8684
# 3       13.7992       14.8060       13.8097     14.8904     11.5533
# 4       13.6592       14.6622       13.6761     14.4914      9.4091
#
#    hsa-let-7d  hsa-let-7e  hsa-let-7f-1  hsa-let-7f-2  hsa-let-7g  ...  \
# 0      9.1296     11.3277        4.5361       13.1852      8.7630  ...
# 1      9.6969      9.6906        4.6816       14.1684      9.4817  ...
# 2      9.0935     10.8985        5.9200       14.9715     10.4961  ...
# 3      9.5417      9.7590        4.8165       13.8766      9.4976  ...
# 4      9.2256      9.4294        6.3407       13.8757      9.8671  ...
#
#    hsa-mir-940  hsa-mir-941-1  hsa-mir-942  hsa-mir-943  hsa-mir-944  \
# 0       1.6747            0.0       2.4290       0.0000       7.0844
# 1       4.0275            0.0       4.3008       0.2781       9.5068
# 2       3.0046            0.0       4.1204       0.0000       8.7194
# 3       3.0337            0.0       3.2618       0.0000       7.5526
# 4       2.4901            0.0       4.7225       0.0000       7.6184
#
#    hsa-mir-95  hsa-mir-96  hsa-mir-98  hsa-mir-99a  hsa-mir-99b
# 0      4.4115      3.2474      5.8341       7.7704      14.8284
# 1      1.5428      5.5523      6.5335       5.1035      14.0989
# 2      4.2529      4.5285      6.3210       4.7599      14.2215
# 3      2.5631      5.6962      6.5749       8.7677      13.6794
# 4      2.6753      4.1333      5.6403       6.3945      13.7741
#
# [5 rows x 842 columns]

# %%
xgb_full = xgboost.DMatrix(df, label=m)
xgb_full

# %%
X_train, X_test, y_train, y_test = train_test_split(df, m, test_size=0.15, random_state=7)
xgb_train = xgboost.DMatrix(X_train, label=y_train)
xgb_test = xgboost.DMatrix(X_test, label=y_test)
y_train.shape
# Out:
# (410,)

# %%
# use validation set to choose # of trees
params = {"eta": 0.002, "max_depth": 3, "objective": "survival:cox", "subsample": 0.5}
model_train = xgboost.train(
    params, xgb_train, 5000, evals=[(xgb_test, "test")], verbose_eval=1000
)
# Out:
# [0]	test-cox-nloglik:3.33229
# [1000]	test-cox-nloglik:3.29762
# [2000]	test-cox-nloglik:3.32535
# [3000]	test-cox-nloglik:3.36571
# [4000]	test-cox-nloglik:3.40249
# [4999]	test-cox-nloglik:3.44119

# %%
#train final model on the full data set
params = {"eta": 0.002, "max_depth": 3, "objective": "survival:cox", "subsample": 0.5}
model = xgboost.train(
    params, xgb_full, 10000, evals=[(xgb_full, "test")], verbose_eval=1000
)
# Out:
# [0]	test-cox-nloglik:5.18603
# [1000]	test-cox-nloglik:4.90164
# [2000]	test-cox-nloglik:4.71441
# [3000]	test-cox-nloglik:4.56850
# [4000]	test-cox-nloglik:4.44971
# [5000]	test-cox-nloglik:4.35008
# [6000]	test-cox-nloglik:4.26507
# [7000]	test-cox-nloglik:4.18975
# [8000]	test-cox-nloglik:4.12286
# [9000]	test-cox-nloglik:4.06481
# [9999]	test-cox-nloglik:4.01136

# %%
def c_statistic_harrell(pred, labels):
    total = 0
    matches = 0
    for i in range(len(labels)):
        for j in range(len(labels)):
            if labels[j] > 0 and abs(labels[i]) > labels[j]:
                total += 1
                if pred[j] > pred[i]:
                    matches += 1
    return matches / total


# see how well we can order people by survival
c_statistic_harrell(model_train.predict(xgb_test), y_test)
# Out:
# 0.5901826484018264

# %%
def c_statistic_harrell(pred, labels):
    total = 0
    matches = 0
    for i in range(len(labels)):
        for j in range(len(labels)):
            if labels[j] > 0 and abs(labels[i]) > labels[j]:
                total += 1
                if pred[j] > pred[i]:
                    matches += 1
    return matches / total


# see how well we can order people by survival
c_statistic_harrell(model.predict(xgb_test), y_test)
# Out:
# 0.9714611872146118

# %%
shap_values = shap.TreeExplainer(model).shap_values(df)
# Out:
# [12:58:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.

# %%
shap.summary_plot(shap_values, df)

# %%
shap_interaction_values = shap.TreeExplainer(model).shap_interaction_values(
    X.iloc[:2000, :]
)
# Out:
# [12:59:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.

# %%
shap.summary_plot(shap_interaction_values, X.iloc[:200, :])

# %%
shap_interaction_values = shap.TreeExplainer(model).shap_interaction_values(
    df.iloc[:2000, :]
)
# Out:
# [00:49:24] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.

# %%
import matplotlib.pylab as pl
import numpy as np
tmp = np.abs(shap_interaction_values).sum(0)
for i in range(tmp.shape[0]):
    tmp[i, i] = 0
inds = np.argsort(-tmp.sum(0))[:50]
tmp2 = tmp[inds, :][:, inds]
pl.figure(figsize=(12, 12))
pl.imshow(tmp2)
pl.yticks(
    range(tmp2.shape[0]), df.columns[inds], rotation=50.4, horizontalalignment="right"
)
pl.xticks(
    range(tmp2.shape[0]), df.columns[inds], rotation=50.4, horizontalalignment="left"
)
pl.gca().xaxis.tick_top()
pl.show()

# %% [markdown]
# ## Lungs Cancer

# %%
import matplotlib.pylab as pl
import xgboost
from sklearn.model_selection import train_test_split

import shap

# %%
import pandas as pd
df = pd.read_csv('miRNA11.csv')
df.head()
# Out:
#    hsa-let-7a-2-3p  hsa-let-7a-3p  hsa-let-7a-5p  hsa-let-7b-3p  \
# 0           0.2372         6.8868        16.0754         4.3936
# 1           0.5782         6.1067        15.5682         5.1750
# 2           0.4842         6.9693        17.2549         6.7587
# 3           0.2998         6.0993        15.4141         4.6114
# 4           0.5061         6.3537        15.9168         5.0323
#
#    hsa-let-7b-5p  hsa-let-7c-3p  hsa-let-7c-5p  hsa-let-7d-3p  hsa-let-7d-5p  \
# 0        12.1407         1.8447        10.3022         7.8107        12.3262
# 1        12.1485         1.9848        10.0580         8.4284        12.1403
# 2        14.3658         3.1662        12.3041         9.3820        12.5467
# 3        12.6769         1.3878         9.7117         7.3923        11.3293
# 4        12.9183         1.7273        10.8604         8.2581        12.1654
#
#    hsa-let-7e-3p  ...  hsa-miR-9500  hsa-miR-96-3p  hsa-miR-96-5p  \
# 0         3.0425  ...             0         0.0000         6.2253
# 1         3.7885  ...             0         0.3179         7.5392
# 2         3.3085  ...             0         0.0000         5.2260
# 3         3.8706  ...             0         1.6224         8.6580
# 4         3.8630  ...             0         0.2751         6.2319
#
#    hsa-miR-98-3p  hsa-miR-98-5p  hsa-miR-99a-3p  hsa-miR-99a-5p  \
# 0         1.7328        11.3658          1.6114         10.2204
# 1         0.7987        10.9484          1.7406         10.0831
# 2         2.3565        10.6058          2.6288         10.5558
# 3         1.6755        10.4907          1.8240          9.9885
# 4         1.5315        11.4967          2.6199         11.2061
#
#    hsa-miR-99b-3p  hsa-miR-99b-5p  OS_days
# 0          6.5796         11.5166     1425
# 1          6.0859         11.3148     1418
# 2          6.3523         10.6756        0
# 3          7.7412         12.8671      422
# 4          6.5427         11.5900      419
#
# [5 rows x 2583 columns]

# %%
Y=df['OS_days']
print(Y)
y=pd.DataFrame(Y)
l=y.to_numpy()

m=l.ravel()

m
# Out:
# 0      1425
# 1      1418
# 2         0
# 3       422
# 4       419
#        ...
# 105     888
# 106      30
# 107    1111
# 108    1106
# 109     820
# Name: OS_days, Length: 110, dtype: int64
# array([1425, 1418,    0,  422,  419,  353,    0,  445,    7,    7, 1837,
#         577, 1805, 1790, 1703,  889, 1794, 1802,  578, 1157,  606,  141,
#         162, 1916,   38, 1801,   23,   73, 1435, 1595,  717, 1617, 1046,
#         594, 1799,  671, 1133,  931, 1376,  627, 1013,  447,  842,  376,
#         308,  355, 1721,    0,  668,   49, 1832, 1848,   60,  382,  474,
#         791,  401,  391,  396,  394,  398,  378,  431,  397,    0,  477,
#         386,    0,  384, 1641,  428,  434,  443,   44,  449,  229,  418,
#         436,  444,  820,  792,  434,  409,  434, 1545,  351,  681, 1086,
#         355, 1081,  303,  403,  405,  413,  423,  423,  443, 1059, 1171,
#         650,  695,  355, 1137,  849, 1135,  888,   30, 1111, 1106,  820],
#       dtype=int64)

# %%
df=df.drop('OS_days', axis=1)
df.head()
# Out:
#    hsa-let-7a-2-3p  hsa-let-7a-3p  hsa-let-7a-5p  hsa-let-7b-3p  \
# 0           0.2372         6.8868        16.0754         4.3936
# 1           0.5782         6.1067        15.5682         5.1750
# 2           0.4842         6.9693        17.2549         6.7587
# 3           0.2998         6.0993        15.4141         4.6114
# 4           0.5061         6.3537        15.9168         5.0323
#
#    hsa-let-7b-5p  hsa-let-7c-3p  hsa-let-7c-5p  hsa-let-7d-3p  hsa-let-7d-5p  \
# 0        12.1407         1.8447        10.3022         7.8107        12.3262
# 1        12.1485         1.9848        10.0580         8.4284        12.1403
# 2        14.3658         3.1662        12.3041         9.3820        12.5467
# 3        12.6769         1.3878         9.7117         7.3923        11.3293
# 4        12.9183         1.7273        10.8604         8.2581        12.1654
#
#    hsa-let-7e-3p  ...  hsa-miR-95-5p  hsa-miR-9500  hsa-miR-96-3p  \
# 0         3.0425  ...         0.0000             0         0.0000
# 1         3.7885  ...         0.0000             0         0.3179
# 2         3.3085  ...         0.0000             0         0.0000
# 3         3.8706  ...         0.2998             0         1.6224
# 4         3.8630  ...         0.0000             0         0.2751
#
#    hsa-miR-96-5p  hsa-miR-98-3p  hsa-miR-98-5p  hsa-miR-99a-3p  \
# 0         6.2253         1.7328        11.3658          1.6114
# 1         7.5392         0.7987        10.9484          1.7406
# 2         5.2260         2.3565        10.6058          2.6288
# 3         8.6580         1.6755        10.4907          1.8240
# 4         6.2319         1.5315        11.4967          2.6199
#
#    hsa-miR-99a-5p  hsa-miR-99b-3p  hsa-miR-99b-5p
# 0         10.2204          6.5796         11.5166
# 1         10.0831          6.0859         11.3148
# 2         10.5558          6.3523         10.6756
# 3          9.9885          7.7412         12.8671
# 4         11.2061          6.5427         11.5900
#
# [5 rows x 2582 columns]

# %%
xgb_full = xgboost.DMatrix(df, label=m)
xgb_full

# %%
X_train, X_test, y_train, y_test = train_test_split(df, m, test_size=0.10, random_state=7)
xgb_train = xgboost.DMatrix(X_train, label=y_train)
xgb_test = xgboost.DMatrix(X_test, label=y_test)
y_train.shape
# Out:
# (99,)

# %%
# use validation set to choose # of trees
params = {"eta": 0.002, "max_depth": 4, "objective": "survival:cox", "subsample": 0.5}
model_train = xgboost.train(
    params, xgb_train, 5000, evals=[(xgb_test, "test")], verbose_eval=1000
)
# Out:
# [0]	test-cox-nloglik:1.59163
# [1000]	test-cox-nloglik:1.68158
# [2000]	test-cox-nloglik:1.74215
# [3000]	test-cox-nloglik:1.78644
# [4000]	test-cox-nloglik:1.83897
# [4999]	test-cox-nloglik:1.87704

# %%
#train final model on the full data set
params = {"eta": 0.001, "max_depth": 2, "objective": "survival:cox", "subsample": 0.5}
model = xgboost.train(
    params, xgb_full, 5000, evals=[(xgb_full, "test")], verbose_eval=1000
)
# Out:
# [0]	test-cox-nloglik:3.68579
# [1000]	test-cox-nloglik:3.45832
# [2000]	test-cox-nloglik:3.28929
# [3000]	test-cox-nloglik:3.15126
# [4000]	test-cox-nloglik:3.03848
# [4999]	test-cox-nloglik:2.94399

# %%
def c_statistic_harrell(pred, labels):
    total = 0
    matches = 0
    for i in range(len(labels)):
        for j in range(len(labels)):
            if labels[j] > 0 and abs(labels[i]) > labels[j]:
                total += 1
                if pred[j] > pred[i]:
                    matches += 1
    return matches / total


# see how well we can order people by survival
c_statistic_harrell(model_train.predict(xgb_test), y_test)
# Out:
# 0.3090909090909091

# %%
def c_statistic_harrell(pred, labels):
    total = 0
    matches = 0
    for i in range(len(labels)):
        for j in range(len(labels)):
            if labels[j] > 0 and abs(labels[i]) > labels[j]:
                total += 1
                if pred[j] > pred[i]:
                    matches += 1
    return matches / total


# see how well we can order people by survival
c_statistic_harrell(model.predict(xgb_test), y_test)
# Out:
# 0.9636363636363636

# %%
shap_values = shap.TreeExplainer(model).shap_values(df)
# Out:
# [01:32:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.

# %%
shap.summary_plot(shap_values, df)
